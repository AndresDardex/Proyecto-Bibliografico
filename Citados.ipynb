# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
datos = pd.read_csv('Search.csv')

# %%
datos.head()
# Out:
#                                              Authors  \
# 0  Parrilla-Escobar M.A.; Quintana-Velasco J.L.; ...
# 1  Gao C.; Liu D.; Xu C.; Xie W.; Zhang X.; Bai J...
# 2  Fiorito A.M.; Blasi G.; Brunelin J.; Chowdury ...
# 3   Suri A.; Avila S.; Tan C.; Alalami H.; Harris J.
# 4  Kopal J.; Kumar K.; Shafighi K.; Saltoun K.; M...
#
#                                    Author full names  \
# 0  Parrilla-Escobar, Maria A. (23989774700); Quin...
# 1  Gao, Changsong (57221930542); Liu, Di (5802881...
# 2  Fiorito, Anna M. (57222185645); Blasi, Giusepp...
# 3  Suri, Abhinav (56694080800); Avila, Stephen (5...
# 4  Kopal, Jakub (56326336800); Kumar, Kuldeep (57...
#
#                                         Author(s) ID  \
# 0  23989774700; 58880527200; 58880527300; 6507213...
# 1  57221930542; 58028818500; 57659168000; 5883839...
# 2  57222185645; 7003486122; 6506018234; 571926563...
# 3  56694080800; 58951164300; 58951322800; 5720505...
# ...

# %%
datos['Cited by'].value_counts()
# Out:
# Cited by
# 0      2701
# 1      1353
# 2       931
# 3       716
# 4       581
#        ...
# 122       1
# 201       1
# 177       1
# 141       1
# 511       1
# Name: count, Length: 165, dtype: int64

# %%
#ordenar el dataframe por la columna 'Cited by'
datos_ordenados_cita = datos.sort_values(by='Cited by', ascending=False)

# %% [markdown]
# # Estos serian los articulos con mas citas en nuestros datos

# %%
datos_ordenados_cita.head()
# Out:
#                                                 Authors  \
# 8858  Toscano G.; Palmerini F.; Ravaglia S.; Ruiz L....
# 9595                   Shen Y.; Gu J.; Tang X.; Zhou B.
# 7817  Hermine O.; Mariette X.; Tharaux P.-L.; Resche...
# 9633                   Lee C.-H.; Liu Z.; Wu L.; Luo P.
# 7257  Xu X.; Tan M.; Corcoran B.; Wu J.; Boes A.; Ng...
#
#                                       Author full names  \
# 8858  Toscano, Gianpaolo (57192834383); Palmerini, F...
# 9595  Shen, Yujun (57207766466); Gu, Jinjin (5721204...
# 7817  Hermine, Olivier (34570066300); Mariette, Xavi...
# 9633  Lee, Cheng-Han (57205626807); Liu, Ziwei (5643...
# 7257  Xu, Xingyuan (57195413608); Tan, Mengxi (57203...
#
#                                            Author(s) ID  \
# 8858  57192834383; 6506911323; 6603598266; 710318442...
# 9595  57207766466; 57212042330; 7404101198; 36697366200
# 7817  34570066300; 7004802753; 6603769366; 136059882...
# 9633  57205626807; 56437024900; 57217987626; 5720304...
# ...
